# %% [markdown]
# # Section 4.2
#
# ## This notebook represent results of the four settings of FIF for the thirteen real-world datasets.
#
# ### As for the boxplots, csv are already uploaded, one can run .py associated (Dyadic_indicator_L2.py, Cosine_L2.py, Cosine_Sobolev.py and Self_L2.py) to re-write the same csv to check their results.
#
# ### The notebook is organized as follows : we import datasets and csv results, then we plots the thirteen ROC curves (and AUC) for each FIF setups.
#
#
# # You can run the entire notebook.

# %% [markdown]
# ## Importing libraries :

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from sklearn.metrics import auc, roc_curve, roc_auc_score
from FIF import *
import os

# %% [markdown]
# ## Function to plot the thirteen Roc Curves :

# %%
def plotroc(y,score):
    y = y
    a , b, _ = roc_curve(y, -score)
    auc = roc_auc_score(y, -score)
    plt.plot(a, b, label=' AUC %.2f' % auc )
    #plt.xlabel('False Positive Rate')
    #plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')

# %% [markdown]
# ## Importing datasets (used only for labels on test sets) :

# %%
#######################################
os.chdir('../../Datasets')
#######################################


chinatown = pd.read_csv('China_Train.csv', header = None)
chinatown2 = pd.read_csv('China_Test.csv', header = None)


X1_train = np.array(chinatown, dtype = float)[:,1:]
X1_test = np.array(chinatown2, dtype = float)[:,1:]
y1_train = np.array(chinatown, dtype=float)[:,0]
y1_test = np.array(chinatown2, dtype=float)[:,0]

coffee = pd.read_csv('Coffee_Train.csv', header = None)
coffee2 = pd.read_csv('Coffee_Test.csv', header = None)


X2_train = np.array(coffee, dtype = float)[:,1:]
X2_test = np.array(coffee2, dtype = float)[:,1:]
y2_train = np.array(coffee, dtype=float)[:,0]
y2_test = np.array(coffee2, dtype=float)[:,0]

ecgfivedays = pd.read_csv('ECGFiveDays_Train.csv', header = None)
ecgfivedays2 = pd.read_csv('ECGFiveDays_Test.csv', header = None)


X3_train = np.array(ecgfivedays, dtype = float)[:,1:]
X3_test = np.array(ecgfivedays2, dtype = float)[:,1:]
y3_train = np.array(ecgfivedays, dtype=float)[:,0]
y3_test = np.array(ecgfivedays2, dtype=float)[:,0]

ecg200 = pd.read_csv('ECG200_Train.csv', header = None)
ecg200_2 = pd.read_csv('ECG200_Test.csv', header = None)


X4_train = np.array(ecg200, dtype = float)[:,1:]
X4_test = np.array(ecg200_2, dtype = float)[:,1:]
y4_train = np.array(ecg200, dtype=float)[:,0]
y4_test = np.array(ecg200_2, dtype=float)[:,0]


handoutlines = pd.read_csv('Handoutlines_Train.csv', header = None)
handoutlines_2 = pd.read_csv('Handoutlines_Test.csv', header = None)


X5_train = np.array(handoutlines, dtype = float)[:,1:]
X5_test = np.array(handoutlines_2, dtype = float)[:,1:]
y5_train = np.array(handoutlines, dtype=float)[:,0]
y5_test = np.array(handoutlines_2, dtype=float)[:,0]





SonyRobotAI1 = pd.read_csv('SonyRobotAI1_Train.csv', header = None)
SonyRobotAI1_2 = pd.read_csv('SonyRobotAI1_Test.csv', header = None)


X6_train = np.array(SonyRobotAI1, dtype = float)[:,1:]
X6_test = np.array(SonyRobotAI1_2, dtype = float)[:,1:]
y6_train = np.array(SonyRobotAI1, dtype=float)[:,0]
y6_test = np.array(SonyRobotAI1_2, dtype=float)[:,0]


SonyRobotAI2 = pd.read_csv('SonyRobotAI2_Train.csv', header = None)
SonyRobotAI2_2 = pd.read_csv('SonyRobotAI2_Test.csv', header = None)


X7_train = np.array(SonyRobotAI2, dtype = float)[:,1:]
X7_test = np.array(SonyRobotAI2_2, dtype = float)[:,1:]
y7_train = np.array(SonyRobotAI2, dtype=float)[:,0]
y7_test = np.array(SonyRobotAI2_2, dtype=float)[:,0]


starlightcurves = pd.read_csv('StarLightCurves_Train.csv', header = None)
starlightcurves2  = pd.read_csv('StarLightCurves_Test1.csv', header = None)
starlightcurves3  = pd.read_csv('StarLightCurves_Test2.csv', header = None)


X8_train = np.array(starlightcurves, dtype = float)[:,1:]
y8_train = np.array(starlightcurves, dtype=float)[:,0]

X8_test1 = np.array(starlightcurves2, dtype = float)[:,1:]
X8_test2 = np.array(starlightcurves3, dtype = float)[:,1:]
X8_test = np.concatenate((X8_test1,X8_test2), axis = 0)
y8_test1 = np.array(starlightcurves2, dtype=float)[:,0]
y8_test2 = np.array(starlightcurves3, dtype=float)[:,0]
y8_test = np.concatenate((y8_test1,y8_test2))


twoleadECG = pd.read_csv('TwoLeadECG_Train.csv', header = None)
twoleadECG2  = pd.read_csv('TwoLeadECG_Test.csv', header = None)


X9_train = np.array(twoleadECG , dtype = float)[:,1:]
X9_test = np.array(twoleadECG2 , dtype = float)[:,1:]
y9_train = np.array(twoleadECG , dtype=float)[:,0]
y9_test = np.array(twoleadECG2 , dtype=float)[:,0]

yoga = pd.read_csv('Yoga_Train.csv', header = None)
yoga2  = pd.read_csv('Yoga_Test.csv', header = None)


X10_train = np.array(yoga , dtype = float)[:,1:]
X10_test = np.array(yoga2 , dtype = float)[:,1:]
y10_train = np.array(yoga , dtype=float)[:,0]
y10_test = np.array(yoga2 , dtype=float)[:,0]

y10_train[np.where(y10_train == 1)[0]] = -1
y10_train[np.where(y10_train == 2)[0]] = 1


EOGHorizontal = pd.read_csv('EOGHorizontal_Train.csv', header = None)
EOGHorizontal2  = pd.read_csv('EOGHorizontal_Test.csv', header = None)


X11_train = np.array(EOGHorizontal , dtype = float)[:,1:]
X11_test = np.array(EOGHorizontal2 , dtype = float)[:,1:]
y11_train = np.array(EOGHorizontal , dtype=float)[:,0]
y11_test = np.array(EOGHorizontal2 , dtype=float)[:,0]

CinECGTorso = pd.read_csv('CinECGTorso_Train.csv', header = None)
CinECGTorso2  = pd.read_csv('CinECGTorso_Test.csv', header = None)


X12_train = np.array(CinECGTorso , dtype = float)[:,1:]
X12_test = np.array(CinECGTorso2 , dtype = float)[:,1:]
y12_train = np.array(CinECGTorso , dtype=float)[:,0]
y12_test = np.array(CinECGTorso2 , dtype=float)[:,0]

ECG5000 = pd.read_csv('ECG5000_Train.csv', header = None)
ECG50002  = pd.read_csv('ECG5000_Test.csv', header = None)


X13_train = np.array(ECG5000 , dtype = float)[:,1:]
X13_test = np.array(ECG50002 , dtype = float)[:,1:]
y13_train = np.array(ECG5000 , dtype=float)[:,0]
y13_test = np.array(ECG50002 , dtype=float)[:,0]

# %% [markdown]
# ## Importing csv with results :

# %%
os.chdir('../Benchmark_methods/Results_FIF')

# %%
fic = open('Results_Dyadic_indicator_L2.csv','r') 
One_score1 = fic.readline()
One_score1 = np.array(One_score1.split(','), dtype = float)
One_score2 = fic.readline()
One_score2 = np.array(One_score2.split(','), dtype = float)
One_score3 = fic.readline()
One_score3 = np.array(One_score3.split(','), dtype = float)
One_score4 = fic.readline()
One_score4 = np.array(One_score4.split(','), dtype = float)
One_score5 = fic.readline()
One_score5 = np.array(One_score5.split(','), dtype = float)
One_score6 = fic.readline()
One_score6 = np.array(One_score6.split(','), dtype = float)
One_score7 = fic.readline()
One_score7 = np.array(One_score7.split(','), dtype = float)
One_score8 = fic.readline()
One_score8 = np.array(One_score8.split(','), dtype = float)
One_score9 = fic.readline()
One_score9 = np.array(One_score9.split(','), dtype = float)
One_score10 = fic.readline()
One_score10 = np.array(One_score10.split(','), dtype = float)
One_score11 = fic.readline()
One_score11 = np.array(One_score11.split(','), dtype = float)
One_score12 = fic.readline()
One_score12 = np.array(One_score12.split(','), dtype = float)
One_score13 = fic.readline()
One_score13 = np.array(One_score13.split(','), dtype = float)

# %%
fic = open('Results_Cosine_Sobolev.csv','r') 
Two_score1 = fic.readline()
Two_score1 = np.array(Two_score1.split(','), dtype = float)
Two_score2 = fic.readline()
Two_score2 = np.array(Two_score2.split(','), dtype = float)
Two_score3 = fic.readline()
Two_score3 = np.array(Two_score3.split(','), dtype = float)
Two_score4 = fic.readline()
Two_score4 = np.array(Two_score4.split(','), dtype = float)
Two_score5 = fic.readline()
Two_score5 = np.array(Two_score5.split(','), dtype = float)
Two_score6 = fic.readline()
Two_score6 = np.array(Two_score6.split(','), dtype = float)
Two_score7 = fic.readline()
Two_score7 = np.array(Two_score7.split(','), dtype = float)
Two_score8 = fic.readline()
Two_score8 = np.array(Two_score8.split(','), dtype = float)
Two_score9 = fic.readline()
Two_score9 = np.array(Two_score9.split(','), dtype = float)
Two_score10 = fic.readline()
Two_score10 = np.array(Two_score10.split(','), dtype = float)
Two_score11 = fic.readline()
Two_score11 = np.array(Two_score11.split(','), dtype = float)
Two_score12 = fic.readline()
Two_score12 = np.array(Two_score12.split(','), dtype = float)
Two_score13 = fic.readline()
Two_score13 = np.array(Two_score13.split(','), dtype = float)

# %%
fic = open('Results_Cosine_L2.csv','r') 
Three_score1 = fic.readline()
Three_score1 = np.array(Three_score1.split(','), dtype = float)
Three_score2 = fic.readline()
Three_score2 = np.array(Three_score2.split(','), dtype = float)
Three_score3 = fic.readline()
Three_score3 = np.array(Three_score3.split(','), dtype = float)
Three_score4 = fic.readline()
Three_score4 = np.array(Three_score4.split(','), dtype = float)
Three_score5 = fic.readline()
Three_score5 = np.array(Three_score5.split(','), dtype = float)
Three_score6 = fic.readline()
Three_score6 = np.array(Three_score6.split(','), dtype = float)
Three_score7 = fic.readline()
Three_score7 = np.array(Three_score7.split(','), dtype = float)
Three_score8 = fic.readline()
Three_score8 = np.array(Three_score8.split(','), dtype = float)
Three_score9 = fic.readline()
Three_score9 = np.array(Three_score9.split(','), dtype = float)
Three_score10 = fic.readline()
Three_score10 = np.array(Three_score10.split(','), dtype = float)
Three_score11 = fic.readline()
Three_score11 = np.array(Three_score11.split(','), dtype = float)
Three_score12 = fic.readline()
Three_score12 = np.array(Three_score12.split(','), dtype = float)
Three_score13 = fic.readline()
Three_score13 = np.array(Three_score13.split(','), dtype = float)

# %%
fic = open('Results_Self_L2.csv','r') 
Self2_score1 = fic.readline()
Self2_score1 = np.array(Self2_score1.split(','), dtype = float)
Self2_score2 = fic.readline()
Self2_score2 = np.array(Self2_score2.split(','), dtype = float)
Self2_score3 = fic.readline()
Self2_score3 = np.array(Self2_score3.split(','), dtype = float)
Self2_score4 = fic.readline()
Self2_score4 = np.array(Self2_score4.split(','), dtype = float)
Self2_score5 = fic.readline()
Self2_score5 = np.array(Self2_score5.split(','), dtype = float)
Self2_score6 = fic.readline()
Self2_score6 = np.array(Self2_score6.split(','), dtype = float)
Self2_score7 = fic.readline()
Self2_score7 = np.array(Self2_score7.split(','), dtype = float)
Self2_score8 = fic.readline()
Self2_score8 = np.array(Self2_score8.split(','), dtype = float)
Self2_score9 = fic.readline()
Self2_score9 = np.array(Self2_score9.split(','), dtype = float)
Self2_score10 = fic.readline()
Self2_score10 = np.array(Self2_score10.split(','), dtype = float)
Self2_score11 = fic.readline()
Self2_score11 = np.array(Self2_score11.split(','), dtype = float)
Self2_score12 = fic.readline()
Self2_score12 = np.array(Self2_score12.split(','), dtype = float)
Self2_score13 = fic.readline()
Self2_score13 = np.array(Self2_score13.split(','), dtype = float)

# %% [markdown]
# # Plots of the Roc Curve for the thirteen datasets w.r.t. the four settings :

# %%
plt.figure(figsize=(16,16))
plt.suptitle('Roc Curve and AUC with Dyadic indicator dictionary and  $L_{2}$ dot product ', size = 30)
plt.subplot(441)
plotroc(y1_test,One_score1)
plt.title('Chinatown')
plt.subplot(442)
plotroc(y2_test,One_score2)
plt.title('Coffee')
plt.subplot(443)
plotroc(y3_test,One_score3)
plt.title('ECGFiveDays')
plt.subplot(444)
plotroc(y4_test,One_score4)
plt.title('ECG200')
plt.subplot(445)
plotroc(y5_test,One_score5)
plt.title("Handoutlines")
plt.subplot(446)
plotroc(y6_test,One_score6)
plt.title('SonyRobotAI1')
plt.subplot(447)
plotroc(y7_test,One_score7)
plt.title('SonyRobotAI2')
plt.subplot(448)
plotroc(y8_test,One_score8)
plt.title('StarLightCurves')
plt.subplot(449)
plotroc(y9_test,One_score9)
plt.title('TwoLeadECG')
plt.subplot(4,4,10)
plotroc(y10_test,One_score10)
plt.title('Yoga')
plt.subplot(4,4,11)
plotroc(y11_test,One_score11)
plt.title("EOGHorizontalSignal")
plt.subplot(4,4,12)
plotroc(y12_test,One_score12)
plt.title('CinECGTorso')
plt.subplot(4,4,13)
plotroc(y13_test,One_score13)
plt.title('ECG5000')
# Out:
# Text(0.5, 1.0, 'ECG5000')

# %%
plt.figure(figsize=(16,16))
plt.suptitle('Roc Curve and AUC with cosinus dictionary and $W_{1,2}$(Sobolev) dot product ', size = 30)
plt.subplot(441)
plotroc(y1_test,Two_score1)
plt.title('Chinatown')
plt.subplot(442)
plotroc(y2_test,Two_score2)
plt.title('Coffee')
plt.subplot(443)
plotroc(y3_test,Two_score3)
plt.title('ECGFiveDays')
plt.subplot(444)
plotroc(y4_test,Two_score4)
plt.title('ECG200')
plt.subplot(445)
plotroc(y5_test,Two_score5)
plt.title("Handoutlines")
plt.subplot(446)
plotroc(y6_test,Two_score6)
plt.title('SonyRobotAI1')
plt.subplot(447)
plotroc(y7_test,Two_score7)
plt.title('SonyRobotAI2')
plt.subplot(448)
plotroc(y8_test,Two_score8)
plt.title('StarLightCurves')
plt.subplot(449)
plotroc(y9_test,Two_score9)
plt.title('TwoLeadECG')
plt.subplot(4,4,10)
plotroc(y10_test,Two_score10)
plt.title('Yoga')
plt.subplot(4,4,11)
plotroc(y11_test,Two_score11)
plt.title("EOGHorizontalSignal")
plt.subplot(4,4,12)
plotroc(y12_test,Two_score12)
plt.title('CinECGTorso')
plt.subplot(4,4,13)
plotroc(y13_test,Two_score13)
plt.title('ECG5000')
# Out:
# Text(0.5, 1.0, 'ECG5000')

# %%
plt.figure(figsize=(16,16))
plt.suptitle('Roc Curve and AUC with cosinus dictionary and $L_{2}$ dot product ', size = 30)
plt.subplot(441)
plotroc(y1_test,Three_score1)
plt.title('Chinatown')
plt.subplot(442)
plotroc(y2_test,Three_score2)
plt.title('Coffee')
plt.subplot(443)
plotroc(y3_test,Three_score3)
plt.title('ECGFiveDays')
plt.subplot(444)
plotroc(y4_test,Three_score4)
plt.title('ECG200')
plt.subplot(445)
plotroc(y5_test,Three_score5)
plt.title("Handoutlines")
plt.subplot(446)
plotroc(y6_test,Three_score6)
plt.title('SonyRobotAI1')
plt.subplot(447)
plotroc(y7_test,Three_score7)
plt.title('SonyRobotAI2')
plt.subplot(448)
plotroc(y8_test,Three_score8)
plt.title('StarLightCurves')
plt.subplot(449)
plotroc(y9_test,Three_score9)
plt.title('TwoLeadECG')
plt.subplot(4,4,10)
plotroc(y10_test,Three_score10)
plt.title('Yoga')
plt.subplot(4,4,11)
plotroc(y11_test,Three_score11)
plt.title("EOGHorizontalSignal")
plt.subplot(4,4,12)
plotroc(y12_test,Three_score12)
plt.title('CinECGTorso')
plt.subplot(4,4,13)
plotroc(y13_test,Three_score13)
plt.title('ECG5000')
# Out:
# Text(0.5, 1.0, 'ECG5000')

# %%
plt.figure(figsize=(16,16))
plt.suptitle('Roc Curve and AUC with Self dictionary and $L_{2}$ dot product ', size = 30)
plt.subplot(441)
plotroc(y1_test,Self2_score1)
plt.title('Chinatown')
plt.subplot(442)
plotroc(y2_test,Self2_score2)
plt.title('Coffee')
plt.subplot(443)
plotroc(y3_test,Self2_score3)
plt.title('ECGFiveDays')
plt.subplot(444)
plotroc(y4_test,Self2_score4)
plt.title('ECG200')
plt.subplot(445)
plotroc(y5_test,Self2_score5)
plt.title("Handoutlines")
plt.subplot(446)
plotroc(y6_test,Self2_score6)
plt.title('SonyRobotAI1')
plt.subplot(447)
plotroc(y7_test,Self2_score7)
plt.title('SonyRobotAI2')
plt.subplot(448)
plotroc(y8_test,Self2_score8)
plt.title('StarLightCurves')
plt.subplot(449)
plotroc(y9_test,Self2_score9)
plt.title('TwoLeadECG')
plt.subplot(4,4,10)
plotroc(y10_test,Self2_score10)
plt.title('Yoga')
plt.subplot(4,4,11)
plotroc(y11_test,Self2_score11)
plt.title("EOGHorizontalSignal")
plt.subplot(4,4,12)
plotroc(y12_test,Self2_score12)
plt.title('CinECGTorso')
plt.subplot(4,4,13)
plotroc(y13_test,Self2_score13)
plt.title('ECG5000')
# Out:
# Text(0.5, 1.0, 'ECG5000')
